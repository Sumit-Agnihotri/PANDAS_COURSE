# %% [markdown]
# # INTRODUCTION TO PANDAS

# %% [markdown]
# ## What is Pandas?
# ### Pandas is a Python library that provides data structures and data analysis tools for data manipulation and analysis. It is built on top of the NumPy package, which means Numpy is required for operating the Pandas.

# %% [markdown]
# ## Why use Pandas?
# ### 1:- Pandas allows us to analyze big data and make conclusions based on statistical theories.
# ### 2:- Pandas can clean messy data sets, and make them readable and relevant.
# ### 3:- Easy Data Cleaning and Transformation.

# %%
print("Introduction to Pandas")
# Out:
# Introduction to Pandas

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Key Data Sructures in Pandas

# %% [markdown]
# ###### * Series (1-Dimensional)
# ###### * DataFrame (2-Dimensional)

# %%
import pandas as pd
s = pd.Series([1,2,3,4,5], index=["A", "B", "C", "D", "E"])
s
# Out:
# A    1
# B    2
# C    3
# D    4
# E    5
# dtype: int64

# %%
df = pd.DataFrame({"Name": ["Sumit", "Rohan", "Trevor"], "Age": [23, 34, 45]}, index=[1,2,3])
df
# Out:
#      Name  Age
# 1   Sumit   23
# 2   Rohan   34
# 3  Trevor   45

# %%
df=pd.read_csv("food delivery costs.csv")

# %%
df.head()
# Out:
#    Order ID Customer ID Restaurant ID  Order Date and Time  \
# 0         1       C8270         R2924  2024-02-01 01:11:52
# 1         2       C1860         R2054  2024-02-02 22:11:04
# 2         3       C6390         R2870  2024-01-31 05:54:35
# 3         4       C6191         R2642  2024-01-16 22:52:49
# 4         5       C6734         R2799  2024-01-29 01:19:30
#
#   Delivery Date and Time  Order Value  Delivery Fee    Payment Method  \
# 0    2024-02-01 02:39:52         1914             0       Credit Card
# 1    2024-02-02 22:46:04          986            40    Digital Wallet
# 2    2024-01-31 06:52:35          937            30  Cash on Delivery
# 3    2024-01-16 23:38:49         1463            50  Cash on Delivery
# 4    2024-01-29 02:48:30         1992            30  Cash on Delivery
#
#   Discounts and Offers  Commission Fee  Payment Processing Fee  \
# 0            5% on App             150                      47
# ...

# %%
df.tail()
# Out:
#      Order ID Customer ID Restaurant ID  Order Date and Time  \
# 995       996       C6232         R2129  2024-01-14 05:57:00
# 996       997       C6797         R2742  2024-01-28 08:50:43
# 997       998       C5926         R2837  2024-01-21 09:43:19
# 998       999       C7016         R2144  2024-01-30 22:23:38
# 999      1000       C4335         R2890  2024-01-08 14:46:43
#
#     Delivery Date and Time  Order Value  Delivery Fee    Payment Method  \
# 995    2024-01-14 06:39:00          825             0    Digital Wallet
# 996    2024-01-28 10:10:43         1627            50  Cash on Delivery
# 997    2024-01-21 10:44:19          553            20  Cash on Delivery
# 998    2024-01-31 00:07:38         1414             0  Cash on Delivery
# 999    2024-01-08 15:39:43         1657            20    Digital Wallet
#
#     Discounts and Offers  Commission Fee  Payment Processing Fee  \
# 995            5% on App             165                      47
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Order ID                1000 non-null   int64
#  1   Customer ID             1000 non-null   object
#  2   Restaurant ID           1000 non-null   object
#  3   Order Date and Time     1000 non-null   object
#  4   Delivery Date and Time  1000 non-null   object
#  5   Order Value             1000 non-null   int64
#  6   Delivery Fee            1000 non-null   int64
#  7   Payment Method          1000 non-null   object
#  8   Discounts and Offers    815 non-null    object
#  9   Commission Fee          1000 non-null   int64
#  10  Payment Processing Fee  1000 non-null   int64
#  11  Refunds/Chargebacks     1000 non-null   int64
# dtypes: int64(6), object(6)
# memory usage: 93.9+ KB

# %% [markdown]
# ## Data Selection

# %%
df["Customer ID"] # Accessing a column
# Out:
# 0      C8270
# 1      C1860
# 2      C6390
# 3      C6191
# 4      C6734
#        ...
# 995    C6232
# 996    C6797
# 997    C5926
# 998    C7016
# 999    C4335
# Name: Customer ID, Length: 1000, dtype: object

# %%
type(df["Customer ID"]) # Series
# Out:
# pandas.core.series.Series

# %%
df[["Customer ID", "Delivery Fee"]] # Selecting multiple columns
# Out:
#     Customer ID  Delivery Fee
# 0         C8270             0
# 1         C1860            40
# 2         C6390            30
# 3         C6191            50
# 4         C6734            30
# ..          ...           ...
# 995       C6232             0
# 996       C6797            50
# 997       C5926            20
# 998       C7016             0
# 999       C4335            20
#
# [1000 rows x 2 columns]

# %%
df.iloc[0] # First row
# Out:
# Order ID                                    1
# Customer ID                             C8270
# Restaurant ID                           R2924
# Order Date and Time       2024-02-01 01:11:52
# Delivery Date and Time    2024-02-01 02:39:52
# Order Value                              1914
# Delivery Fee                                0
# Payment Method                    Credit Card
# Discounts and Offers                5% on App
# Commission Fee                            150
# Payment Processing Fee                     47
# Refunds/Chargebacks                         0
# Name: 0, dtype: object

# %%
df2=pd.read_csv("food delivery costs 2.csv")
df2
# Out:
#      Order ID Customer ID Restaurant ID  Order Date and Time  \
# 0           1       C8270         R2924  2024-02-01 01:11:52
# 1           2       C1860         R2054  2024-02-02 22:11:04
# 2           3       C6390         R2870  2024-01-31 05:54:35
# 3           4       C6191         R2642  2024-01-16 22:52:49
# 4           5       C6734         R2799  2024-01-29 01:19:30
# ..        ...         ...           ...                  ...
# 995       996       C6232         R2129  2024-01-14 05:57:00
# 996       997       C6797         R2742  2024-01-28 08:50:43
# 997       998       C5926         R2837  2024-01-21 09:43:19
# 998       999       C7016         R2144  2024-01-30 22:23:38
# 999      1000       C4335         R2890  2024-01-08 14:46:43
#
#     Delivery Date and Time  Order Value  Delivery Fee    Payment Method  \
# 0      2024-02-01 02:39:52         1914             0       Credit Card
# 1      2024-02-02 22:46:04          986            40    Digital Wallet
# ...

# %%
df2.dropna() # drop rows with missing values
df2.fillna(0) # fill missing values with 0
# Out:
#      Order ID Customer ID Restaurant ID  Order Date and Time  \
# 0           1       C8270         R2924  2024-02-01 01:11:52
# 1           2       C1860         R2054  2024-02-02 22:11:04
# 2           3       C6390         R2870  2024-01-31 05:54:35
# 3           4       C6191         R2642  2024-01-16 22:52:49
# 4           5       C6734         R2799  2024-01-29 01:19:30
# ..        ...         ...           ...                  ...
# 995       996       C6232         R2129  2024-01-14 05:57:00
# 996       997       C6797         R2742  2024-01-28 08:50:43
# 997       998       C5926         R2837  2024-01-21 09:43:19
# 998       999       C7016         R2144  2024-01-30 22:23:38
# 999      1000       C4335         R2890  2024-01-08 14:46:43
#
#     Delivery Date and Time  Order Value  Delivery Fee    Payment Method  \
# 0      2024-02-01 02:39:52         1914             0       Credit Card
# 1      2024-02-02 22:46:04          986            40    Digital Wallet
# ...

# %%
df2.rename(columns={"Order ID": "ID"}, inplace=True) # rename columns
df2
# Out:
#        ID Customer ID Restaurant ID  Order Date and Time  \
# 0       1       C8270         R2924  2024-02-01 01:11:52
# 1       2       C1860         R2054  2024-02-02 22:11:04
# 2       3       C6390         R2870  2024-01-31 05:54:35
# 3       4       C6191         R2642  2024-01-16 22:52:49
# 4       5       C6734         R2799  2024-01-29 01:19:30
# ..    ...         ...           ...                  ...
# 995   996       C6232         R2129  2024-01-14 05:57:00
# 996   997       C6797         R2742  2024-01-28 08:50:43
# 997   998       C5926         R2837  2024-01-21 09:43:19
# 998   999       C7016         R2144  2024-01-30 22:23:38
# 999  1000       C4335         R2890  2024-01-08 14:46:43
#
#     Delivery Date and Time  Order Value  Delivery Fee    Payment Method  \
# 0      2024-02-01 02:39:52         1914             0       Credit Card
# 1      2024-02-02 22:46:04          986            40    Digital Wallet
# ...

# %%
df2.describe() # summary statistics
# Out:
#                 ID  Order Value  Delivery Fee  Commission Fee  \
# count  1000.000000  1000.000000   1000.000000      1000.00000
# mean    500.500000  1053.969000     28.620000       126.99000
# std     288.819436   530.975339     16.958278        43.06405
# min       1.000000   104.000000      0.000000        50.00000
# 25%     250.750000   597.750000     20.000000        90.00000
# 50%     500.500000  1038.500000     30.000000       127.00000
# 75%     750.250000  1494.000000     40.000000       164.00000
# max    1000.000000  1995.000000     50.000000       200.00000
#
#        Payment Processing Fee  Refunds/Chargebacks
# count             1000.000000          1000.000000
# mean                29.832000            28.300000
# std                 11.627165            49.614228
# min                 10.000000             0.000000
# 25%                 20.000000             0.000000
# 50%                 30.000000             0.000000
# ...

# %%
df2.info() # information about the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      1000 non-null   int64
#  1   Customer ID             1000 non-null   object
#  2   Restaurant ID           1000 non-null   object
#  3   Order Date and Time     1000 non-null   object
#  4   Delivery Date and Time  1000 non-null   object
#  5   Order Value             1000 non-null   int64
#  6   Delivery Fee            1000 non-null   int64
#  7   Payment Method          1000 non-null   object
#  8   Discounts and Offers    815 non-null    object
#  9   Commission Fee          1000 non-null   int64
#  10  Payment Processing Fee  1000 non-null   int64
#  11  Refunds/Chargebacks     1000 non-null   int64
# dtypes: int64(6), object(6)
# memory usage: 93.9+ KB

# %%
df2['ID'] = df2['ID'].astype(str) # change data type
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      1000 non-null   object
#  1   Customer ID             1000 non-null   object
#  2   Restaurant ID           1000 non-null   object
#  3   Order Date and Time     1000 non-null   object
#  4   Delivery Date and Time  1000 non-null   object
#  5   Order Value             1000 non-null   int64
#  6   Delivery Fee            1000 non-null   int64
#  7   Payment Method          1000 non-null   object
#  8   Discounts and Offers    815 non-null    object
#  9   Commission Fee          1000 non-null   int64
#  10  Payment Processing Fee  1000 non-null   int64
#  11  Refunds/Chargebacks     1000 non-null   int64
# dtypes: int64(5), object(7)
# memory usage: 93.9+ KB

# %%
df.to_excel("food delivery costs 2.xlsx", index=False) # write to excel

# %%
df3=pd.DataFrame({"Name": ["Sumit", "Rohan", "Trevor"], "Age": [23, 34, 45]})
df3
# Out:
#      Name  Age
# 0   Sumit   23
# 1   Rohan   34
# 2  Trevor   45

# %%
df4=pd.DataFrame({"Name": ["Shikha", "Reema", "Shiba"], "Age": [19,20,21]})
df4
# Out:
#      Name  Age
# 0  Shikha   19
# 1   Reema   20
# 2   Shiba   21

# %%
pd.concat([df3, df4]) # concatenate dataframes
# Out:
#      Name  Age
# 0   Sumit   23
# 1   Rohan   34
# 2  Trevor   45
# 0  Shikha   19
# 1   Reema   20
# 2   Shiba   21
